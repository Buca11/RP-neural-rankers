# %%
#Install dependencies
# %pip install pandas numpy pyserini fast-forward-indexes==0.2.0  ir_measures ir_datasets faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 64.7 MB/s eta 0:00:0000:0100:01
# Collecting numpy
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 50.5 MB/s eta 0:00:0000:0100:01
# Collecting pyserini
#   Downloading pyserini-0.35.0-py3-none-any.whl (168.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.6/168.6 MB 13.0 MB/s eta 0:00:0000:0100:01
# Collecting fast-forward-indexes==0.2.0
#   Downloading fast_forward_indexes-0.2.0-py3-none-any.whl (25 kB)
# Collecting ir_measures
#   Using cached ir_measures-0.3.3-py3-none-any.whl
# Collecting ir_datasets
#   Downloading ir_datasets-0.5.7-py3-none-any.whl (337 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.9/337.9 KB 9.9 MB/s eta 0:00:00a 0:00:01
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 21.9 MB/s eta 0:00:0000:0100:01
# Collecting transformers>=4.28.0
#   Downloading transformers-4.41.2-py3-none-any.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 16.7 MB/s eta 0:00:0000:0100:01
# Collecting torch>=2.0.0
#   Downloading torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 770.0 kB/s eta 0:00:0000:0100:01
# Collecting tqdm
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 KB 2.6 MB/s eta 0:00:00
# Collecting h5py>=3.0.0
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 19.2 MB/s eta 0:00:0000:0100:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 KB 34.2 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 KB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lucia/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from pyserini) (5.4.1)
# Collecting onnxruntime>=1.8.1
#   Downloading onnxruntime-1.18.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 29.9 MB/s eta 0:00:0000:0100:01
# Collecting scipy>=1.4.1
#   Downloading scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 25.3 MB/s eta 0:00:0000:0100:01
# Collecting pillow>=10.2.0
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 29.7 MB/s eta 0:00:0000:0100:01
# Collecting spacy>=3.2.1
#   Downloading spacy-3.7.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 29.7 MB/s eta 0:00:0000:0100:01
# Collecting tiktoken>=0.4.0
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.9 MB/s eta 0:00:0000:01
# Collecting openai>=1.0.0
#   Downloading openai-1.33.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 KB 14.1 MB/s eta 0:00:00
# Collecting nmslib>=2.1.1
#   Using cached nmslib-2.1.1-cp310-cp310-linux_x86_64.whl
# Collecting lightgbm>=3.3.2
#   Downloading lightgbm-4.3.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 31.0 MB/s eta 0:00:0000:0100:01
# Collecting Cython>=0.29.21
#   Downloading Cython-3.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 33.8 MB/s eta 0:00:0000:0100:01
# Collecting sentencepiece>=0.1.95
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.3 MB/s eta 0:00:0000:01
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 25.4 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn>=0.22.1
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 34.1 MB/s eta 0:00:0000:0100:01
# Collecting pyjnius>=1.4.0
#   Downloading pyjnius-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 25.1 MB/s eta 0:00:00a 0:00:01
# Collecting pytrec-eval-terrier>=0.5.5
#   Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 KB 11.5 MB/s eta 0:00:00
# Collecting cwl-eval>=1.0.10
#   Using cached cwl_eval-1.0.12-py3-none-any.whl
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting lz4>=3.1.10
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.2 MB/s eta 0:00:0000:01
# Collecting warc3-wet-clueweb09>=0.2.5
#   Using cached warc3_wet_clueweb09-0.2.5-py3-none-any.whl
# Collecting inscriptis>=2.2.0
#   Downloading inscriptis-2.5.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 KB 6.5 MB/s eta 0:00:00
# Collecting requests>=2.22.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 9.0 MB/s eta 0:00:00
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting ijson>=3.1.3
#   Downloading ijson-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 KB 5.8 MB/s eta 0:00:00
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting lxml>=4.5.2
#   Downloading lxml-5.2.2-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 17.6 MB/s eta 0:00:0000:0100:01
# Collecting zlib-state>=0.1.3
#   Using cached zlib_state-0.1.6-cp310-cp310-linux_x86_64.whl
# Collecting beautifulsoup4>=4.4.1
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 KB 21.8 MB/s eta 0:00:00
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 KB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /home/lucia/.local/lib/python3.10/site-packages (from nmslib>=2.1.1->pyserini) (5.9.8)
# Collecting sympy
#   Downloading sympy-1.12.1-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 22.0 MB/s eta 0:00:0000:0100:01
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 1.5 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-5.27.1-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 KB 16.4 MB/s eta 0:00:00
# Collecting flatbuffers
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging in /home/lucia/.local/lib/python3.10/site-packages (from onnxruntime>=1.8.1->pyserini) (24.0)
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 KB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/lucia/.local/lib/python3.10/site-packages (from openai>=1.0.0->pyserini) (4.12.2)
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.7.3-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 KB 13.9 MB/s eta 0:00:00
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.0.0->pyserini) (1.7.0)
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 9.9 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.4/164.4 KB 13.7 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 6.0 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 2.5 MB/s eta 0:00:00a 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 KB 26.5 MB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 KB 6.6 MB/s eta 0:00:00
# Collecting jinja2
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 KB 21.0 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy>=3.2.1->pyserini) (59.6.0)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 KB 19.2 MB/s eta 0:00:00
# Collecting weasel<0.5.0,>=0.1.0
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 KB 7.3 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 KB 7.4 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting thinc<8.3.0,>=8.2.2
#   Downloading thinc-8.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (922 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.4/922.4 KB 19.9 MB/s eta 0:00:0000:01
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.0/493.0 KB 26.4 MB/s eta 0:00:00
# Collecting typer<1.0.0,>=0.3.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 KB 8.6 MB/s eta 0:00:00
# Collecting regex>=2022.1.18
#   Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (775 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 KB 30.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.20.5
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.1.3.1
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.1.105
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 10.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 484.9 kB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.0.2.54
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 16.3 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.1 MB/s eta 0:00:00a 0:00:01
# Collecting triton==2.3.1
#   Downloading triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 10.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 22.6 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.1.0.106
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 10.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.4.5.107
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu12==12.1.105
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 24.8 MB/s eta 0:00:0000:0100:01
# Collecting fsspec
#   Downloading fsspec-2024.6.0-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.9/176.9 KB 21.2 MB/s eta 0:00:00
# Collecting filelock
#   Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 KB 24.9 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 19.9 MB/s eta 0:00:0000:0100:01
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.8 MB/s eta 0:00:00a 0:00:01
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.7 MB/s eta 0:00:0000:0100:01
# Collecting huggingface-hub<1.0,>=0.23.0
#   Downloading huggingface_hub-0.23.3-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.7/401.7 KB 12.2 MB/s eta 0:00:00
# Collecting cbor>=1.0.0
#   Using cached cbor-1.0.0-py3-none-any.whl
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/lucia/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.0.0->pyserini) (1.2.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 KB 12.3 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 6.8 MB/s eta 0:00:00
# Collecting language-data>=1.2
#   Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 28.0 MB/s eta 0:00:0000:0100:01
# Collecting pydantic-core==2.18.4
#   Downloading pydantic_core-2.18.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.3 MB/s eta 0:00:0000:0100:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 19.9 MB/s eta 0:00:0000:010:01
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 30.3 MB/s eta 0:00:00
# Collecting click>=8.0.0
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 KB 14.2 MB/s eta 0:00:00
# Collecting smart-open<8.0.0,>=5.2.1
#   Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 KB 5.4 MB/s eta 0:00:00
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 KB 4.7 MB/s eta 0:00:00
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 8.3 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting mpmath<1.4.0,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 22.4 MB/s eta 0:00:00
# Collecting marisa-trie>=0.7.7
#   Downloading marisa_trie-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.0 MB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/lucia/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.2.1->pyserini) (2.18.0)
# Collecting wrapt
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 KB 3.1 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, sentencepiece, pytz, pyjnius, mpmath, ijson, flatbuffers, cymem, cbor, zlib-state, wrapt, wasabi, urllib3, unlzw3, tzdata, tqdm, threadpoolctl, sympy, spacy-loggers, spacy-legacy, soupsieve, sniffio, shellingham, safetensors, regex, pytrec-eval-terrier, pydantic-core, pybind11, protobuf, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, murmurhash, mdurl, MarkupSafe, marisa-trie, lz4, lxml, joblib, idna, humanfriendly, h11, fsspec, filelock, Cython, cloudpathlib, click, charset-normalizer, certifi, catalogue, annotated-types, triton, trec-car-tools, srsly, smart-open, scipy, requests, pydantic, pyarrow, preshed, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nmslib, markdown-it-py, language-data, jinja2, httpcore, h5py, faiss-cpu, cwl-eval, coloredlogs, blis, beautifulsoup4, anyio, tiktoken, scikit-learn, rich, onnxruntime, nvidia-cusolver-cu12, lightgbm, langcodes, ir_measures, inscriptis, huggingface-hub, httpx, confection, typer, torch, tokenizers, thinc, openai, ir_datasets, weasel, transformers, spacy, fast-forward-indexes, pyserini
# Successfully installed Cython-3.0.10 MarkupSafe-2.1.5 annotated-types-0.7.0 anyio-4.4.0 beautifulsoup4-4.12.3 blis-0.7.11 catalogue-2.0.10 cbor-1.0.0 certifi-2024.6.2 charset-normalizer-3.3.2 click-8.1.7 cloudpathlib-0.18.1 coloredlogs-15.0.1 confection-0.1.5 cwl-eval-1.0.12 cymem-2.0.8 faiss-cpu-1.8.0 fast-forward-indexes-0.2.0 filelock-3.14.0 flatbuffers-24.3.25 fsspec-2024.6.0 h11-0.14.0 h5py-3.11.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.23.3 humanfriendly-10.0 idna-3.7 ijson-3.3.0 inscriptis-2.5.0 ir_datasets-0.5.7 ir_measures-0.3.3 jinja2-3.1.4 joblib-1.4.2 langcodes-3.4.0 language-data-1.2.0 lightgbm-4.3.0 lxml-5.2.2 lz4-4.3.3 marisa-trie-1.2.0 markdown-it-py-3.0.0 mdurl-0.1.2 mpmath-1.3.0 murmurhash-1.0.10 networkx-3.3 nmslib-2.1.1 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 onnxruntime-1.18.0 openai-1.33.0 pandas-2.2.2 pillow-10.3.0 preshed-3.0.9 protobuf-5.27.1 pyarrow-16.1.0 pybind11-2.6.1 pydantic-2.7.3 pydantic-core-2.18.4 pyjnius-1.6.1 pyserini-0.35.0 pytrec-eval-terrier-0.5.6 pytz-2024.1 regex-2024.5.15 requests-2.32.3 rich-13.7.1 safetensors-0.4.3 scikit-learn-1.5.0 scipy-1.13.1 sentencepiece-0.2.0 shellingham-1.5.4 smart-open-7.0.4 sniffio-1.3.1 soupsieve-2.5 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 sympy-1.12.1 thinc-8.2.4 threadpoolctl-3.5.0 tiktoken-0.7.0 tokenizers-0.19.1 torch-2.3.1 tqdm-4.66.4 transformers-4.41.2 trec-car-tools-2.6 triton-2.3.1 typer-0.12.3 tzdata-2024.1 unlzw3-0.2.2 urllib3-2.2.1 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0 zlib-state-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Dense retrieval with TCT Colbert

# %%
import pandas as pd
import numpy as np
import ir_datasets
import ir_measures
from ir_measures import *
from beir import util
from beir.datasets.data_loader import GenericDataLoader
import json
from pyserini.search.faiss import FaissSearcher, TctColBertQueryEncoder
from fast_forward import Ranking
from pathlib import Path

# %%
# Download dataset
url = "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/fiqa.zip"
data_path = util.download_and_unzip(url, 'fiqa')
corpus, queries, qrels = GenericDataLoader(data_folder=data_path).load(split="test")

# %%
#Convert dataset to Pyserini expected format
input_file = '/fiqa/fiqa/corpus.jsonl'  
output_file = '/fiqa/fiqa/corpus-converted.jsonl'  

with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
    for line in infile:
        entry = json.loads(line)
        contents_with_newline = entry["text"] + "\n" 
        new_entry = {
            "id": entry["_id"],
            "contents": contents_with_newline
        }
        outfile.write(json.dumps(new_entry) + '\n')

# %%
#Encode the converted corpus in the terminal using TCT-ColBERT encoder
python3 -m pyserini.encode 
  input   --corpus fiqa/fiqa/corpus-converted.jsonl       
          --fields text      
          --delimiter "\n" 
          --shard-id 0
          --shard-num 1 
  output  --embeddings fiqa/embd
          --to-faiss 
  encoder --encoder castorini/tct_colbert-msmarco 
          --fields text 
          --batch 32 
          --fp16

# %%
#Create dense index using encoded corpus
python3 -m pyserini.index.faiss --input fiqa/embd --output fiqa/dense_index

# %%
def generate_df(searcher, dataset):
    query_ids = []
    doc_ids = []
    scores = []
    for query in dataset.queries_iter():
        hits = searcher.search(query[1],k=1000)
        for hit in hits:
            query_ids.append(query[0])
            doc_ids.append(hit.docid)
            scores.append(hit.score)
    df = pd.DataFrame({
        'q_id': query_ids,
        'id': doc_ids,
        'score': scores
    })
    return df

# %%
encoder = TctColBertQueryEncoder('castorini/tct_colbert-msmarco')
#Create searcher for dense retrieval
dsearcher = FaissSearcher('fiqa/dense_index',encoder)
devset_name = 'irds:beir/fiqa/dev'
devset = ir_datasets.load(devset_name)
df = generate_df(dsearcher,devset)
r = Ranking(df,name = 'TCT')
#Save dense retrieval Results
r.save(Path('trec-run-tct-fiqa-dev.txt'))

# %%
#Generate test set results for dense retrieval
testset_name = 'irds:beir/fiqa/test'
testset = ir_datasets.load(testset_name)
df = generate_df(dsearcher,testset)
r = Ranking(df,name = 'TCT')
r.save(Path('trec-run-tct-fiqa-test.txt'))

# %% [markdown]
# Hybrid Retrieval

# %%
#Hyperparameter turning without normalizing the scores
alpha_range = [0.05, 0.1, 0.25,0.5, 0.75,0.9] 
dr = Ranking.from_file(Path('trec-run-tct-fiqa-dev.txt'))
sr = Ranking.from_file(Path('trec-run-bm25_fiqa-dev.txt'))
for alpha in alpha_range:
    hybrid = sr.interpolate(dr,alpha)
    hybrid.save(Path('trec-run-bm25-tct-fiqa-dev-int-'+str(alpha) +'.txt'))

# %%
path = 'trec-run-bm25-tct-fiqa-dev-int-'
results = []
for alpha in alpha_range:
    full_path = path+str(alpha)+'.txt'
    run = ir_measures.read_trec_run(full_path)
    qrels = devset.qrels_iter()
    res = ir_measures.calc_aggregate([RR @ 10, nDCG @ 10, MAP @ 100, R@ 100, AP @ 10], qrels, run)
    results.append(res)
df = pd.DataFrame(results, index=[f'{alpha}' for alpha in alpha_range])
df.to_csv('hybrid-original-fiqa-scores-alpha-tuning.csv')
best_alpha_idx = df.iloc[:, 4].idxmax()
best_original = float(best_alpha_idx)

# %%
def normalize_column(df, column_name):
    min_val = df[column_name].min()
    max_val = df[column_name].max()
    df[column_name] = (df[column_name] - min_val) / (max_val - min_val)

# %%
#Hyperparameter tuning for hybrid retrieval with normalized scores
ddf = dr._df
normalize_column(ddf,'score')
sdf = sr._df
normalize_column(sdf,'score')
for alpha in alpha_range:
    hybrid = sr.interpolate(dr,alpha)
    hybrid.save(Path('trec-run-bm25-tct-fiqa-dev-int-'+str(alpha) +'-normalized.txt'))

# %%
path = 'trec-run-bm25-tct-fiqa-dev-int-'
results = []
for alpha in alpha_range:
    full_path = path+str(alpha)+'-normalized.txt'
    run = ir_measures.read_trec_run(full_path)
    qrels = devset.qrels_iter()
    res = ir_measures.calc_aggregate([RR @ 10, nDCG @ 10, MAP @ 100, R@ 100, AP @ 10], qrels, run)
    results.append(res)
df = pd.DataFrame(results, index=[f'{alpha}' for alpha in alpha_range])
df.to_csv('hybrid-original-fiqa-scores-alpha-tuning-normalized.csv')
best_normalized = float(df.iloc[:, 4].idxmax())

# %%
#Manipulation of dataframes to implement missing score techniques
def deal_with_missing_scores_and_interpolate(dense_path, sparse_path, method, alpha, normalize):
    dense_ranking = Ranking.from_file(Path(dense_path))
    sparse_ranking = Ranking.from_file(Path(sparse_path))
    full = None
    if (method == 'zero'):
        merged = dense_ranking._df.merge(sparse_ranking._df, on=["q_id", "id"],how = 'outer', suffixes=['_dense', "_sparse"])
        merged['score_dense'] = merged['score_dense'].fillna(0)
        merged['score_sparse'] = merged['score_sparse'].fillna(0)
        full = merged
    if (method == 'average'):
        merged = dense_ranking._df.merge(sparse_ranking._df, on=["q_id", "id"],how = 'outer', suffixes=['_dense', "_sparse"])
        merged['score_dense'] = merged['score_dense'].fillna(merged["score_dense"].mean())
        merged['score_sparse'] = merged['score_sparse'].fillna(merged["score_sparse"].mean())
        full = merged
    if (method == 'drop'):
        merged = dense_ranking._df.merge(sparse_ranking._df, on=["q_id", "id"],how = 'inner', suffixes=['_dense', "_sparse"])
        full = merged
    if (method == 'median'):
        merged = dense_ranking._df.merge(sparse_ranking._df, on=["q_id", "id"],how = 'outer', suffixes=['_dense', "_sparse"])
        merged['score_dense'] = merged['score_dense'].fillna(merged["score_dense"].median())
        merged['score_sparse'] = merged['score_sparse'].fillna(merged["score_sparse"].median())
        full = merged
    if normalize:
        normalize_column(full,'score_dense')
        normalize_column(full,'score_sparse')
    full["score"] = alpha * full['score_sparse'] + (1 - alpha) * full['score_dense']
    result = Ranking(
            full,
            name='hybrid',
            dtype=np.float32,
            copy=False,
            is_sorted=False,
        )
    return result

# %%
missing_scores = ['average','median','zero','drop']
dense_test = 'trec-run-tct-fiqa-test.txt'
sparse_test = 'trec-run-bm25_fiqa-test-0.1.txt'
for score in missing_scores:
    r = deal_with_missing_scores_and_interpolate(dense_test, sparse_test,score,best_original,False)
    r.save(Path('trec-run-bm25-tct-fiqa-test-int-'+str(best_original)+'-'+score+'.txt'))

# %%
path = 'trec-run-bm25-tct-fiqa-test-int-'+str(best_original)+'-'
results = []
for score in missing_scores:
    full_path = path+score+'.txt'
    run = ir_measures.read_trec_run(full_path)
    qrels = testset.qrels_iter()
    res = ir_measures.calc_aggregate( [RR(rel=2) @ 10, nDCG @ 10, MAP(rel=2)@10, R(rel=2)@ 100, AP(rel=2) @ 10], qrels, run)
    results.append(res)
df = pd.DataFrame(results, index=[f'Score {score}' for score in missing_scores])
df.to_csv('hybrid-original-fiqa-missing-score '+str(best_original)+'-test-results.csv')

# %%
for score in missing_scores:
    r = deal_with_missing_scores_and_interpolate(dense_test, sparse_test,score,best_normalized,True)
    r.save(Path('trec-run-bm25-tct-fiqa-test-int-'+str(best_normalized)+'-norm-'+score+'.txt'))

# %%
path = 'trec-run-bm25-tct-fiqa-test-int-'+str(best_normalized)+'-norm-'
results = []
for score in missing_scores:
    full_path = path+score+'.txt'
    run = ir_measures.read_trec_run(full_path)
    qrels = testset.qrels_iter()
    res = ir_measures.calc_aggregate( [RR @ 10, nDCG @ 10,  R@ 100], qrels, run)
    results.append(res)
df = pd.DataFrame(results, index=[f'Score {score}' for score in missing_scores])
df.to_csv('hybrid-fiqa-norm-missing-score '+str(best_normalized)+'-test-results.csv')
